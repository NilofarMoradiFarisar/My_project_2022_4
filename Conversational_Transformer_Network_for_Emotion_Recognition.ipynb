# %% [markdown]
# <a href="https://colab.research.google.com/github/NilofarMoradiFarisar/My_project_2022_4/blob/main/Conversational_Transformer_Network_for_Emotion_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchtext
import torch.nn as nn
from torch.autograd import Variable
from torch.nn import functional as F

import math
import numpy as np
import copy
import time

import pandas as pd
from sklearn.model_selection import train_test_split


import os
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

import pickle
import random
import librosa
import librosa.display
import IPython.display
import warnings
warnings.filterwarnings(action='ignore')


from google.colab import drive
drive.mount('/content/G')
# Out:
# Drive already mounted at /content/G; to attempt to forcibly remount, call drive.mount("/content/G", force_remount=True).

# %%
path_to_train_dataset = "/content/G/MyDrive/VED/EMO-DB-CLASSIFIED-0.1/train/"
path_to_test_dataset = "/content/G/MyDrive/VED/EMO-DB-CLASSIFIED-0.1/test/"

# %%
def get_abs_subdir_files(path_to_folder):

    filelist = []
    for root, dirs, files in os.walk(path_to_folder):
        for file in files:
            filelist.append(os.path.join(root,file))

    return filelist



def remove_silent_space(signal, sr=22050, threshold=0.0005):
    mask = []
    signal_abs = pd.Series(signal).apply(np.abs)
    signal_mean = signal_abs.rolling(window = int(sr/10), min_periods = 1, center = True).mean()
    for mean in signal_mean:
        if mean > threshold:
            mask.append(True)
        else:
            mask.append(False)
    return np.array(signal[mask])




def get_label(file):

    emotion_mappings  = {
                            "A" : 0,
                            "T" : 1,
                            "E" : 2,
                            "W" : 3,
                            "L" : 4,
                            "N" : 5,
                            "F" : 6
                        }

    return emotion_mappings[file[-6:-5]]



def get_voice_features(signal, sample_rate=22050, n_fft = 2048, hop_length = 512, n_mfcc = 13):

    voice_features = []
    signal = signal[:22050]
    voice_features.append(librosa.feature.mfcc(signal, sr=sample_rate, n_fft = n_fft, hop_length=hop_length, n_mfcc=n_mfcc))
    voice_features.append(librosa.feature.melspectrogram(signal, sr=sample_rate, n_fft = n_fft, hop_length=hop_length))
    voice_features.append(librosa.feature.chroma_stft(signal, sr=sample_rate, n_fft = n_fft, hop_length=hop_length))
    voice_features.append(librosa.feature.spectral_contrast(signal, sr=sample_rate, n_fft = n_fft, hop_length=hop_length))
    voice_features.append(librosa.feature.tonnetz(signal, sr=sample_rate, hop_length=hop_length))

    signal_harmonic, signal_percussive = librosa.effects.hpss(signal)
    melspec_harmonic = librosa.feature.melspectrogram(signal_harmonic, n_mels = 64)
    melspec_percussive = librosa.feature.melspectrogram(signal_percussive, n_mels = 64)
    hpss_hp = np.average([melspec_harmonic, melspec_percussive], axis=0)

    voice_features.append(hpss_hp)


    image_width = voice_features[0].shape[1]
    image_height = 0
    for v_feat in voice_features:
        image_height += v_feat.shape[0]


    start_index = 0
    feature = np.zeros((image_height, image_width))
    for v_feat in voice_features:
        feature[start_index: start_index + v_feat.shape[0], :] = v_feat
        start_index += v_feat.shape[0]

    feature = torch.from_numpy(feature.astype(np.float32))

    return (feature.T)



class EMODB_Dataset(Dataset):

    def __init__(self, path_to_audio_waves, sample_rate=22050):

        self.audio_waves = get_abs_subdir_files(path_to_audio_waves)
        self.sample_rate = sample_rate
        self.labels = []
        self.features = []

        for idx in range(len(self.audio_waves)):
            audio_file = self.audio_waves[idx]
            signal, sr = librosa.load(audio_file, sr=self.sample_rate)
            signal = remove_silent_space(signal, sr=sr)
            
            label = get_label(audio_file)

            label = np.array(label)
            label = torch.from_numpy(label)
            self.features.append(get_voice_features(signal))
            self.labels.append(label)


    def __len__(self):
        return len(self.audio_waves)

    def __getitem__(self, idx):

        return self.features[idx], self.labels[idx]

# %%
training_data = EMODB_Dataset(path_to_train_dataset)
test_data = EMODB_Dataset(path_to_test_dataset)

# %%
train_loader = DataLoader(training_data, batch_size=8, shuffle=True)
test_loader = DataLoader(test_data, batch_size=8, shuffle=True)

batch = next(iter(train_loader))
batch[0].shape, batch[1].shape
# Out:
# (torch.Size([8, 44, 230]), torch.Size([8]))

# %%
class PositionalEncoder(nn.Module):
    def __init__(self, d_model, max_seq_len = 32):
        super().__init__()
        self.d_model = d_model
        pe = torch.zeros(max_seq_len, d_model)

        for pos in range(max_seq_len):
            for i in range(0, d_model, 2):
                pe[pos, i] = \
                math.sin(pos / (10000 ** ((2 * i)/d_model)))
                pe[pos, i + 1] = \
                math.cos(pos / (10000 ** ((2 * (i + 1))/d_model)))
                
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)
 
    
    def forward(self, x):
        x = x * math.sqrt(self.d_model)
        seq_len = x.size(1)
        x = x + Variable(self.pe[:,:seq_len], requires_grad=False).cuda()
        return x

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, heads, d_model, dropout = 0.1):
        super().__init__()
        
        self.d_model = d_model
        self.d_k = d_model // heads
        self.h = heads
        
        self.q_linear = nn.Linear(d_model, d_model)
        self.v_linear = nn.Linear(d_model, d_model)
        self.k_linear = nn.Linear(d_model, d_model)
        self.dropout = nn.Dropout(dropout)
        self.out = nn.Linear(d_model, d_model)
    
    def forward(self, q, k, v, mask=None):
        
        bs = q.size(0)
                
        k = self.k_linear(k).view(bs, -1, self.h, self.d_k)
        q = self.q_linear(q).view(bs, -1, self.h, self.d_k)
        v = self.v_linear(v).view(bs, -1, self.h, self.d_k)
        
       
        k = k.transpose(1,2)
        q = q.transpose(1,2)
        v = v.transpose(1,2)
        scores = attention(q, k, v, self.d_k, mask, self.dropout)
        
        concat = scores.transpose(1,2).contiguous().view(bs, -1, self.d_model)
        output = self.out(concat)
    
        return output

# %%
def attention(q, k, v, d_k, mask=None, dropout=None):
    
    scores = torch.matmul(q, k.transpose(-2, -1)) /  math.sqrt(d_k)

    if mask is not None:
            mask = mask.unsqueeze(1)
            scores = scores.masked_fill(mask == 0, -1e9)
    scores = F.softmax(scores, dim=-1)
    
    if dropout is not None:
        scores = dropout(scores)
    output = torch.matmul(scores, v)
    
    return output

# %%
class FeedForward(nn.Module):
    def __init__(self, d_model, d_ff=2048, dropout = 0.5):
        super().__init__() 
        # We set d_ff as a default to 2048
        self.linear_1 = nn.Linear(d_model, d_ff)
        self.dropout = nn.Dropout(dropout)
        self.linear_2 = nn.Linear(d_ff, d_model)
    def forward(self, x):
        x = self.dropout(F.relu(self.linear_1(x)))
        x = self.linear_2(x)
        return x

# %%
class Norm(nn.Module):
    def __init__(self, d_model, eps = 1e-6):
        super().__init__()
    
        self.size = d_model
        # create two learnable parameters to calibrate normalisation
        self.alpha = nn.Parameter(torch.ones(self.size))
        self.bias = nn.Parameter(torch.zeros(self.size))
        self.eps = eps
    def forward(self, x):
        norm = self.alpha * (x - x.mean(dim=-1, keepdim=True)) / (x.std(dim=-1, keepdim=True) + self.eps) + self.bias
        return norm

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, heads, dropout = 0.1):
        super().__init__()
        self.norm_1 = Norm(d_model)
        self.norm_2 = Norm(d_model)
        self.attn = MultiHeadAttention(heads, d_model)
        self.ff = FeedForward(d_model)
        self.dropout_1 = nn.Dropout(dropout)
        self.dropout_2 = nn.Dropout(dropout)
        
    def forward(self, x, mask):
        x2 = self.norm_1(x)
        x = x + self.dropout_1(self.attn(x2,x2,x2,mask))
        x2 = self.norm_2(x)
        x = x + self.dropout_2(self.ff(x2))
        return x

def get_clones(module, N):
    return nn.ModuleList([copy.deepcopy(module) for i in range(N)])

# %%
class Encoder(nn.Module):
    def __init__(self, input_channel, d_model, N, heads, output_channel=32, frame_attention=True):
        super().__init__()
        self.frame_attention = frame_attention
        self.N = N
        self.conv1d = torch.nn.Conv1d(input_channel, output_channel, 15, stride=1)
        self.pe = PositionalEncoder(d_model)
        self.layers = get_clones(EncoderLayer(d_model, heads), N)
        self.norm = Norm(d_model)

        self.Wz = Variable(torch.randn(d_model, 1).type(torch.FloatTensor), requires_grad=True).to("cuda")
        self.bz = Variable(torch.randn(output_channel, 1).type(torch.FloatTensor), requires_grad=True).to("cuda")

        self.fc = nn.Linear(d_model, 7)
        self.dropout = nn.Dropout()

    def forward(self, x, mask=None):
        x = self.conv1d(x)
        x = self.pe(x).cuda()
        for i in range(N):
            x = self.layers[i](x.cuda(), None)

        #Frame-based Attention Mechanism
        if self.frame_attention:
            logit = x @ self.Wz + self.bz
            alpha_fuse = F.softmax(logit, dim=1)
            alpha_fuse = alpha_fuse.transpose(dim0=1, dim1=2)
            x = alpha_fuse @ x
            x = x.reshape(-1, d_model)
            print("self",x.shape)
        else:
            x = x[:, -1, :]


        x = self.fc(x)
        x = self.dropout(x)

        return x

# %%
# m = torch.nn.Conv1d(44, 44, 15, stride=1)
# input = torch.randn(20, 44, 216)
# n = m(input)
# input.shape, m(input).shape

# %%
# import torch
# from torch.autograd import Variable

# d_model = 216
# input_channel = 32
# batch = 8

# input = torch.randn(batch, input_channel, d_model)


# dtype = torch.FloatTensor
# N, D_in, H, D_out = 64, 1000, 100, 10

# Wz = Variable(torch.randn(d_model, 1).type(dtype), requires_grad=True)
# bz = Variable(torch.randn(input_channel, 1).type(dtype), requires_grad=True)
# logit = input @ Wz + bz
# alpha_fuse = F.softmax(logit, dim=1)
# alpha_fuse = alpha_fuse.transpose(dim0=1, dim1=2)
# best_output = alpha_fuse @ input
# best_output = best_output.reshape(-1, d_model)

# %%
d_model = 216
heads = 8
N = 6
input_channel = 44

model = Encoder(input_channel, d_model, N, heads, frame_attention=False)

for p in model.parameters():
    if p.dim() > 1:
        nn.init.xavier_uniform_(p)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.98), eps=1e-9)
criterion = nn.CrossEntropyLoss()

# %%
model.to("cuda")
# Out:
# Encoder(
#   (conv1d): Conv1d(44, 32, kernel_size=(15,), stride=(1,))
#   (pe): PositionalEncoder()
#   (layers): ModuleList(
#     (0): EncoderLayer(
#       (norm_1): Norm()
#       (norm_2): Norm()
#       (attn): MultiHeadAttention(
#         (q_linear): Linear(in_features=216, out_features=216, bias=True)
#         (v_linear): Linear(in_features=216, out_features=216, bias=True)
#         (k_linear): Linear(in_features=216, out_features=216, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (out): Linear(in_features=216, out_features=216, bias=True)
#       )
#       (ff): FeedForward(
#         (linear_1): Linear(in_features=216, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.5, inplace=False)
#         (linear_2): Linear(in_features=2048, out_features=216, bias=True)
#       )
#       (dropout_1): Dropout(p=0.1, inplace=False)
#       (dropout_2): Dropout(p=0.1, inplace=False)
#     )
#     (1): EncoderLayer(
#       (norm_1): Norm()
#       (norm_2): Norm()
#       (attn): MultiHeadAttention(
#         (q_linear): Linear(in_features=216, out_features=216, bias=True)
#         (v_linear): Linear(in_features=216, out_features=216, bias=True)
#         (k_linear): Linear(in_features=216, out_features=216, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (out): Linear(in_features=216, out_features=216, bias=True)
#       )
#       (ff): FeedForward(
#         (linear_1): Linear(in_features=216, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.5, inplace=False)
#         (linear_2): Linear(in_features=2048, out_features=216, bias=True)
#       )
#       (dropout_1): Dropout(p=0.1, inplace=False)
#       (dropout_2): Dropout(p=0.1, inplace=False)
#     )
#     (2): EncoderLayer(
#       (norm_1): Norm()
#       (norm_2): Norm()
#       (attn): MultiHeadAttention(
#         (q_linear): Linear(in_features=216, out_features=216, bias=True)
#         (v_linear): Linear(in_features=216, out_features=216, bias=True)
#         (k_linear): Linear(in_features=216, out_features=216, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (out): Linear(in_features=216, out_features=216, bias=True)
#       )
#       (ff): FeedForward(
#         (linear_1): Linear(in_features=216, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.5, inplace=False)
#         (linear_2): Linear(in_features=2048, out_features=216, bias=True)
#       )
#       (dropout_1): Dropout(p=0.1, inplace=False)
#       (dropout_2): Dropout(p=0.1, inplace=False)
#     )
#     (3): EncoderLayer(
#       (norm_1): Norm()
#       (norm_2): Norm()
#       (attn): MultiHeadAttention(
#         (q_linear): Linear(in_features=216, out_features=216, bias=True)
#         (v_linear): Linear(in_features=216, out_features=216, bias=True)
#         (k_linear): Linear(in_features=216, out_features=216, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (out): Linear(in_features=216, out_features=216, bias=True)
#       )
#       (ff): FeedForward(
#         (linear_1): Linear(in_features=216, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.5, inplace=False)
#         (linear_2): Linear(in_features=2048, out_features=216, bias=True)
#       )
#       (dropout_1): Dropout(p=0.1, inplace=False)
#       (dropout_2): Dropout(p=0.1, inplace=False)
#     )
#     (4): EncoderLayer(
#       (norm_1): Norm()
#       (norm_2): Norm()
#       (attn): MultiHeadAttention(
#         (q_linear): Linear(in_features=216, out_features=216, bias=True)
#         (v_linear): Linear(in_features=216, out_features=216, bias=True)
#         (k_linear): Linear(in_features=216, out_features=216, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (out): Linear(in_features=216, out_features=216, bias=True)
#       )
#       (ff): FeedForward(
#         (linear_1): Linear(in_features=216, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.5, inplace=False)
#         (linear_2): Linear(in_features=2048, out_features=216, bias=True)
#       )
#       (dropout_1): Dropout(p=0.1, inplace=False)
#       (dropout_2): Dropout(p=0.1, inplace=False)
#     )
#     (5): EncoderLayer(
#       (norm_1): Norm()
#       (norm_2): Norm()
#       (attn): MultiHeadAttention(
#         (q_linear): Linear(in_features=216, out_features=216, bias=True)
#         (v_linear): Linear(in_features=216, out_features=216, bias=True)
#         (k_linear): Linear(in_features=216, out_features=216, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (out): Linear(in_features=216, out_features=216, bias=True)
#       )
#       (ff): FeedForward(
#         (linear_1): Linear(in_features=216, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.5, inplace=False)
#         (linear_2): Linear(in_features=2048, out_features=216, bias=True)
#       )
#       (dropout_1): Dropout(p=0.1, inplace=False)
#       (dropout_2): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (norm): Norm()
#   (fc): Linear(in_features=216, out_features=7, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
# for inputs, targets in train_loader:
#     inputs, targets = inputs.to("cuda"), targets.to("cuda")
#     outputs = model(inputs,mask=None)
#     loss = criterion(outputs, targets)
#     print (loss)
#     break

# %%
def get_test_dataset_accuracy(test_loader, device="cuda:0"):
    
    n_correct = 0.
    n_total = 0.
    predictions_total = []
    targets_total = []

    for inputs, targets in test_loader:

        inputs, targets = inputs.to(device), targets.to(device)
        outputs = model(inputs)
        _, predictions = torch.max(outputs, 1)
        n_correct += (predictions == targets).sum().item()
        n_total += targets.shape[0]
        predictions_total += list(predictions.to("cpu").numpy().astype(int))
        targets_total += list(targets.to("cpu").numpy().astype(int))

    return n_correct / n_total, predictions_total, targets_total

# %%
def batch_gd(model, criterion, optimizer, train_loader, test_loader, epochs, device="cuda"):
  
  accuracy_best = -1
  train_losses = np.zeros(epochs)
  test_losses = np.zeros(epochs)

  for it in range(epochs):
    model.train()
    t0 = datetime.now()
    train_loss = []
    for inputs, targets in train_loader:

      inputs, targets = inputs.to(device), targets.to(device)
      optimizer.zero_grad()
      outputs = model(inputs)
      loss = criterion(outputs, targets)

      loss.backward()
      optimizer.step()
      train_loss.append(loss.item())

    train_loss = np.mean(train_loss) # a little misleading
    
    model.eval()
    test_loss = []
    for inputs, targets in test_loader:
      inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)
      loss = criterion(outputs, targets)
      test_loss.append(loss.item())
    test_loss = np.mean(test_loss)
    

    # Save losses
    train_losses[it] = train_loss
    test_losses[it] = test_loss
    

    accuracy_test,  predictions_total, targets_total = get_test_dataset_accuracy(test_loader, device="cuda:0")
    accuracy_train,  predictions_total, targets_total = get_test_dataset_accuracy(train_loader, device="cuda:0")


    dt = datetime.now() - t0

    print(f'Epoch {it+1}/{epochs}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, accuracy_train: {accuracy_train:.4f}, accuracy_test: {accuracy_test:.4f}, Duration: {dt}')
        
  return train_losses, test_losses

# %% [markdown]
# # Results taken from last layer (Best 0.68)

# %%
train_losses, test_losses = batch_gd(model, criterion, optimizer, train_loader, test_loader, epochs=200)
# Out:
# Epoch 1/200, Train Loss: 912.0397, Test Loss: 452.3109, accuracy_train: 0.2971, accuracy_test: 0.2766, Duration: 0:00:01.952119
# Epoch 2/200, Train Loss: 426.3029, Test Loss: 324.7593, accuracy_train: 0.4816, accuracy_test: 0.4043, Duration: 0:00:01.819651
# Epoch 3/200, Train Loss: 297.5868, Test Loss: 298.1315, accuracy_train: 0.5553, accuracy_test: 0.4043, Duration: 0:00:01.786297
# Epoch 4/200, Train Loss: 175.3705, Test Loss: 184.6307, accuracy_train: 0.5697, accuracy_test: 0.3191, Duration: 0:00:01.807451
# Epoch 5/200, Train Loss: 132.5955, Test Loss: 182.1044, accuracy_train: 0.6230, accuracy_test: 0.4468, Duration: 0:00:01.795618
# Epoch 6/200, Train Loss: 131.1731, Test Loss: 172.4223, accuracy_train: 0.5963, accuracy_test: 0.4043, Duration: 0:00:01.769391
# Epoch 7/200, Train Loss: 96.3859, Test Loss: 201.6052, accuracy_train: 0.6680, accuracy_test: 0.4043, Duration: 0:00:01.776223
# Epoch 8/200, Train Loss: 79.1019, Test Loss: 161.1593, accuracy_train: 0.7049, accuracy_test: 0.5745, Duration: 0:00:01.768299
# Epoch 9/200, Train Loss: 72.2114, Test Loss: 132.2980, accuracy_train: 0.8115, accuracy_test: 0.5106, Duration: 0:00:02.705229
# Epoch 10/200, Train Loss: 52.5736, Test Loss: 148.4167, accuracy_train: 0.7623, accuracy_test: 0.4894, Duration: 0:00:01.753767
# Epoch 11/200, Train Loss: 46.5283, Test Loss: 164.0134, accuracy_train: 0.8156, accuracy_test: 0.4894, Duration: 0:00:01.773706
# Epoch 12/200, Train Loss: 53.7254, Test Loss: 140.1756, accuracy_train: 0.8484, accuracy_test: 0.5957, Duration: 0:00:01.747038
# Epoch 13/200, Train Loss: 51.4851, Test Loss: 128.6335, accuracy_train: 0.7807, accuracy_test: 0.5532, Duration: 0:00:01.759712
# Epoch 14/200, Train Loss: 41.7404, Test Loss: 145.4600, accuracy_train: 0.8750, accuracy_test: 0.5319, Duration: 0:00:01.798231
# Epoch 15/200, Train Loss: 38.7060, Test Loss: 139.1914, accuracy_train: 0.8648, accuracy_test: 0.5532, Duration: 0:00:01.768614
# Epoch 16/200, Train Loss: 42.0178, Test Loss: 162.4146, accuracy_train: 0.8545, accuracy_test: 0.5106, Duration: 0:00:01.795300
# Epoch 17/200, Train Loss: 38.2999, Test Loss: 167.8518, accuracy_train: 0.8504, accuracy_test: 0.5532, Duration: 0:00:01.773811
# Epoch 18/200, Train Loss: 32.4764, Test Loss: 156.5100, accuracy_train: 0.8873, accuracy_test: 0.5106, Duration: 0:00:01.767858
# Epoch 19/200, Train Loss: 26.4710, Test Loss: 164.4586, accuracy_train: 0.8955, accuracy_test: 0.4681, Duration: 0:00:01.770500
# Epoch 20/200, Train Loss: 37.0249, Test Loss: 195.6677, accuracy_train: 0.9037, accuracy_test: 0.4894, Duration: 0:00:01.794467
# Epoch 21/200, Train Loss: 21.8825, Test Loss: 164.4303, accuracy_train: 0.8791, accuracy_test: 0.4894, Duration: 0:00:01.749994
# Epoch 22/200, Train Loss: 31.1723, Test Loss: 193.2188, accuracy_train: 0.9160, accuracy_test: 0.4894, Duration: 0:00:01.765691
# Epoch 23/200, Train Loss: 29.5535, Test Loss: 195.6222, accuracy_train: 0.9139, accuracy_test: 0.4894, Duration: 0:00:01.773898
# Epoch 24/200, Train Loss: 25.4435, Test Loss: 178.2029, accuracy_train: 0.8914, accuracy_test: 0.5106, Duration: 0:00:01.819976
# Epoch 25/200, Train Loss: 24.5806, Test Loss: 178.0219, accuracy_train: 0.9324, accuracy_test: 0.5957, Duration: 0:00:01.774644
# Epoch 26/200, Train Loss: 25.5734, Test Loss: 209.1556, accuracy_train: 0.9283, accuracy_test: 0.4043, Duration: 0:00:01.769027
# Epoch 27/200, Train Loss: 19.1905, Test Loss: 206.3590, accuracy_train: 0.9283, accuracy_test: 0.4468, Duration: 0:00:01.872537
# Epoch 28/200, Train Loss: 28.6187, Test Loss: 170.9772, accuracy_train: 0.9365, accuracy_test: 0.5957, Duration: 0:00:01.779681
# Epoch 29/200, Train Loss: 20.4585, Test Loss: 195.9936, accuracy_train: 0.9365, accuracy_test: 0.4681, Duration: 0:00:01.774826
# Epoch 30/200, Train Loss: 24.2233, Test Loss: 200.5146, accuracy_train: 0.9590, accuracy_test: 0.4894, Duration: 0:00:01.856429
# Epoch 31/200, Train Loss: 15.2087, Test Loss: 163.3181, accuracy_train: 0.9324, accuracy_test: 0.4894, Duration: 0:00:01.767667
# Epoch 32/200, Train Loss: 19.2133, Test Loss: 173.1920, accuracy_train: 0.9570, accuracy_test: 0.5532, Duration: 0:00:01.807642
# Epoch 33/200, Train Loss: 14.6061, Test Loss: 228.9778, accuracy_train: 0.9324, accuracy_test: 0.3617, Duration: 0:00:01.740622
# Epoch 34/200, Train Loss: 12.5865, Test Loss: 213.4880, accuracy_train: 0.9734, accuracy_test: 0.6383, Duration: 0:00:01.813424
# Epoch 35/200, Train Loss: 17.4536, Test Loss: 202.0841, accuracy_train: 0.9734, accuracy_test: 0.5106, Duration: 0:00:01.827714
# Epoch 36/200, Train Loss: 20.6601, Test Loss: 221.6003, accuracy_train: 0.9529, accuracy_test: 0.5106, Duration: 0:00:01.834071
# Epoch 37/200, Train Loss: 14.9913, Test Loss: 233.3709, accuracy_train: 0.9406, accuracy_test: 0.5745, Duration: 0:00:01.776496
# Epoch 38/200, Train Loss: 22.5481, Test Loss: 291.0070, accuracy_train: 0.9385, accuracy_test: 0.4468, Duration: 0:00:01.750467
# Epoch 39/200, Train Loss: 17.7863, Test Loss: 243.2561, accuracy_train: 0.9652, accuracy_test: 0.5532, Duration: 0:00:01.836100
# Epoch 40/200, Train Loss: 16.4359, Test Loss: 251.9617, accuracy_train: 0.9488, accuracy_test: 0.4681, Duration: 0:00:01.823020
# Epoch 41/200, Train Loss: 15.1868, Test Loss: 234.2464, accuracy_train: 0.9447, accuracy_test: 0.5319, Duration: 0:00:01.811371
# Epoch 42/200, Train Loss: 17.7865, Test Loss: 265.7908, accuracy_train: 0.9775, accuracy_test: 0.4894, Duration: 0:00:01.789908
# Epoch 43/200, Train Loss: 14.4986, Test Loss: 251.5895, accuracy_train: 0.9775, accuracy_test: 0.4681, Duration: 0:00:01.782722
# Epoch 44/200, Train Loss: 13.5133, Test Loss: 246.1202, accuracy_train: 0.9816, accuracy_test: 0.4681, Duration: 0:00:01.776666
# Epoch 45/200, Train Loss: 9.1562, Test Loss: 239.5908, accuracy_train: 0.9652, accuracy_test: 0.5532, Duration: 0:00:01.746112
# Epoch 46/200, Train Loss: 16.1428, Test Loss: 274.4254, accuracy_train: 0.9816, accuracy_test: 0.5745, Duration: 0:00:01.819702
# Epoch 47/200, Train Loss: 12.4002, Test Loss: 283.3909, accuracy_train: 0.9877, accuracy_test: 0.5957, Duration: 0:00:01.780800
# Epoch 48/200, Train Loss: 14.4754, Test Loss: 273.3673, accuracy_train: 0.9467, accuracy_test: 0.4468, Duration: 0:00:01.768472
# Epoch 49/200, Train Loss: 17.9342, Test Loss: 331.4420, accuracy_train: 0.9570, accuracy_test: 0.5957, Duration: 0:00:01.781773
# Epoch 50/200, Train Loss: 10.6568, Test Loss: 305.4719, accuracy_train: 0.9754, accuracy_test: 0.4468, Duration: 0:00:01.758110
# Epoch 51/200, Train Loss: 11.5486, Test Loss: 333.5404, accuracy_train: 0.9898, accuracy_test: 0.4468, Duration: 0:00:01.778788
# Epoch 52/200, Train Loss: 11.6476, Test Loss: 305.5586, accuracy_train: 0.9795, accuracy_test: 0.5319, Duration: 0:00:01.778088
# Epoch 53/200, Train Loss: 16.4328, Test Loss: 333.1507, accuracy_train: 0.9836, accuracy_test: 0.5319, Duration: 0:00:01.753785
# Epoch 54/200, Train Loss: 13.5449, Test Loss: 342.8488, accuracy_train: 0.9734, accuracy_test: 0.5745, Duration: 0:00:01.775532
# Epoch 55/200, Train Loss: 6.7999, Test Loss: 294.0323, accuracy_train: 0.9693, accuracy_test: 0.5319, Duration: 0:00:01.786038
# Epoch 56/200, Train Loss: 16.3461, Test Loss: 325.7724, accuracy_train: 0.9857, accuracy_test: 0.5532, Duration: 0:00:01.806311
# Epoch 57/200, Train Loss: 12.2222, Test Loss: 322.6140, accuracy_train: 0.9775, accuracy_test: 0.4894, Duration: 0:00:01.787384
# Epoch 58/200, Train Loss: 6.7266, Test Loss: 322.8294, accuracy_train: 0.9898, accuracy_test: 0.5319, Duration: 0:00:01.771669
# Epoch 59/200, Train Loss: 6.8410, Test Loss: 315.6133, accuracy_train: 0.9939, accuracy_test: 0.5532, Duration: 0:00:01.808021
# Epoch 60/200, Train Loss: 10.3195, Test Loss: 361.6598, accuracy_train: 0.9734, accuracy_test: 0.5106, Duration: 0:00:01.819419
# Epoch 61/200, Train Loss: 16.5666, Test Loss: 249.2719, accuracy_train: 1.0000, accuracy_test: 0.5957, Duration: 0:00:01.819454
# Epoch 62/200, Train Loss: 6.3627, Test Loss: 250.1443, accuracy_train: 0.9836, accuracy_test: 0.5745, Duration: 0:00:01.777542
# Epoch 63/200, Train Loss: 12.8265, Test Loss: 357.5773, accuracy_train: 0.9918, accuracy_test: 0.5319, Duration: 0:00:01.845441
# Epoch 64/200, Train Loss: 12.0492, Test Loss: 347.2175, accuracy_train: 0.9877, accuracy_test: 0.5745, Duration: 0:00:01.816717
# Epoch 65/200, Train Loss: 8.4575, Test Loss: 392.5845, accuracy_train: 0.9939, accuracy_test: 0.5319, Duration: 0:00:01.771512
# Epoch 66/200, Train Loss: 7.7722, Test Loss: 451.4761, accuracy_train: 0.9816, accuracy_test: 0.5106, Duration: 0:00:02.172796
# Epoch 67/200, Train Loss: 17.1392, Test Loss: 356.8610, accuracy_train: 0.9939, accuracy_test: 0.5532, Duration: 0:00:01.773395
# Epoch 68/200, Train Loss: 7.8327, Test Loss: 378.5578, accuracy_train: 0.9775, accuracy_test: 0.5106, Duration: 0:00:01.765208
# Epoch 69/200, Train Loss: 9.5811, Test Loss: 351.0990, accuracy_train: 0.9918, accuracy_test: 0.5957, Duration: 0:00:01.833866
# Epoch 70/200, Train Loss: 12.0563, Test Loss: 364.5920, accuracy_train: 0.9898, accuracy_test: 0.4894, Duration: 0:00:01.783147
# Epoch 71/200, Train Loss: 10.3513, Test Loss: 417.4594, accuracy_train: 0.9775, accuracy_test: 0.4681, Duration: 0:00:01.805812
# Epoch 72/200, Train Loss: 13.9516, Test Loss: 413.6448, accuracy_train: 0.9898, accuracy_test: 0.5532, Duration: 0:00:01.784913
# Epoch 73/200, Train Loss: 8.1414, Test Loss: 382.3575, accuracy_train: 0.9959, accuracy_test: 0.5319, Duration: 0:00:01.766408
# Epoch 74/200, Train Loss: 7.6676, Test Loss: 371.6578, accuracy_train: 0.9836, accuracy_test: 0.5957, Duration: 0:00:01.831072
# Epoch 75/200, Train Loss: 11.8326, Test Loss: 330.7292, accuracy_train: 0.9898, accuracy_test: 0.5745, Duration: 0:00:01.805114
# Epoch 76/200, Train Loss: 7.3219, Test Loss: 336.1600, accuracy_train: 0.9939, accuracy_test: 0.5745, Duration: 0:00:01.787488
# Epoch 77/200, Train Loss: 10.1296, Test Loss: 400.4121, accuracy_train: 0.9775, accuracy_test: 0.5319, Duration: 0:00:01.767677
# Epoch 78/200, Train Loss: 13.1610, Test Loss: 326.3593, accuracy_train: 0.9836, accuracy_test: 0.5745, Duration: 0:00:01.825287
# Epoch 79/200, Train Loss: 8.7179, Test Loss: 434.6304, accuracy_train: 0.9898, accuracy_test: 0.5745, Duration: 0:00:01.794142
# Epoch 80/200, Train Loss: 4.2142, Test Loss: 436.7250, accuracy_train: 0.9795, accuracy_test: 0.5106, Duration: 0:00:01.813473
# Epoch 81/200, Train Loss: 15.0287, Test Loss: 487.2109, accuracy_train: 0.9857, accuracy_test: 0.5532, Duration: 0:00:01.770113
# Epoch 82/200, Train Loss: 8.7656, Test Loss: 453.1786, accuracy_train: 0.9918, accuracy_test: 0.4894, Duration: 0:00:01.825473
# Epoch 83/200, Train Loss: 11.8010, Test Loss: 386.6241, accuracy_train: 0.9918, accuracy_test: 0.4894, Duration: 0:00:01.778892
# Epoch 84/200, Train Loss: 4.9622, Test Loss: 398.9511, accuracy_train: 0.9980, accuracy_test: 0.5106, Duration: 0:00:01.832406
# Epoch 85/200, Train Loss: 10.2530, Test Loss: 431.6044, accuracy_train: 0.9918, accuracy_test: 0.5957, Duration: 0:00:01.772185
# Epoch 86/200, Train Loss: 6.1164, Test Loss: 463.0726, accuracy_train: 0.9877, accuracy_test: 0.4894, Duration: 0:00:01.773273
# Epoch 87/200, Train Loss: 8.8623, Test Loss: 361.6617, accuracy_train: 0.9857, accuracy_test: 0.4894, Duration: 0:00:01.807527
# Epoch 88/200, Train Loss: 17.2536, Test Loss: 357.0065, accuracy_train: 0.9877, accuracy_test: 0.5745, Duration: 0:00:01.756052
# Epoch 89/200, Train Loss: 11.2115, Test Loss: 392.8224, accuracy_train: 0.9959, accuracy_test: 0.5957, Duration: 0:00:02.132937
# Epoch 90/200, Train Loss: 8.0773, Test Loss: 375.7858, accuracy_train: 0.9959, accuracy_test: 0.6809, Duration: 0:00:01.806366
# Epoch 91/200, Train Loss: 13.6900, Test Loss: 362.7378, accuracy_train: 0.9857, accuracy_test: 0.5106, Duration: 0:00:01.762401
# Epoch 92/200, Train Loss: 8.8812, Test Loss: 357.6594, accuracy_train: 0.9898, accuracy_test: 0.6170, Duration: 0:00:01.760821
# Epoch 93/200, Train Loss: 4.7343, Test Loss: 382.4182, accuracy_train: 0.9816, accuracy_test: 0.6383, Duration: 0:00:01.787442
# Epoch 94/200, Train Loss: 12.5469, Test Loss: 351.2460, accuracy_train: 0.9980, accuracy_test: 0.6170, Duration: 0:00:01.775073
# Epoch 95/200, Train Loss: 6.1604, Test Loss: 358.0469, accuracy_train: 0.9939, accuracy_test: 0.5745, Duration: 0:00:02.172883
# Epoch 96/200, Train Loss: 12.4434, Test Loss: 382.2751, accuracy_train: 0.9939, accuracy_test: 0.5532, Duration: 0:00:02.726865
# Epoch 97/200, Train Loss: 17.8361, Test Loss: 396.7269, accuracy_train: 0.9898, accuracy_test: 0.6170, Duration: 0:00:01.771284
# Epoch 98/200, Train Loss: 6.3003, Test Loss: 361.6784, accuracy_train: 0.9918, accuracy_test: 0.5957, Duration: 0:00:01.776352
# Epoch 99/200, Train Loss: 13.8277, Test Loss: 411.5956, accuracy_train: 0.9959, accuracy_test: 0.6170, Duration: 0:00:01.787882
# Epoch 100/200, Train Loss: 4.6840, Test Loss: 432.8625, accuracy_train: 0.9898, accuracy_test: 0.6170, Duration: 0:00:01.797335
# Epoch 101/200, Train Loss: 5.4693, Test Loss: 435.8015, accuracy_train: 0.9775, accuracy_test: 0.5319, Duration: 0:00:01.754218
# Epoch 102/200, Train Loss: 17.2486, Test Loss: 512.9315, accuracy_train: 0.9898, accuracy_test: 0.6170, Duration: 0:00:01.799800
# Epoch 103/200, Train Loss: 7.1993, Test Loss: 456.5544, accuracy_train: 0.9959, accuracy_test: 0.5957, Duration: 0:00:01.758510
# Epoch 104/200, Train Loss: 4.9130, Test Loss: 500.7605, accuracy_train: 0.9877, accuracy_test: 0.6170, Duration: 0:00:01.796741
# Epoch 105/200, Train Loss: 10.5251, Test Loss: 474.2367, accuracy_train: 0.9959, accuracy_test: 0.5532, Duration: 0:00:01.820167
# Epoch 106/200, Train Loss: 8.0953, Test Loss: 451.5950, accuracy_train: 0.9898, accuracy_test: 0.6383, Duration: 0:00:01.782839
# Epoch 107/200, Train Loss: 14.7559, Test Loss: 458.6455, accuracy_train: 0.9857, accuracy_test: 0.5745, Duration: 0:00:01.750561
# Epoch 108/200, Train Loss: 8.1278, Test Loss: 509.1874, accuracy_train: 0.9939, accuracy_test: 0.5957, Duration: 0:00:01.779960
# Epoch 109/200, Train Loss: 13.2258, Test Loss: 514.1235, accuracy_train: 0.9980, accuracy_test: 0.4894, Duration: 0:00:01.824959
# Epoch 110/200, Train Loss: 10.2167, Test Loss: 633.4924, accuracy_train: 0.9877, accuracy_test: 0.4894, Duration: 0:00:01.758973
# Epoch 111/200, Train Loss: 15.3843, Test Loss: 505.8837, accuracy_train: 0.9939, accuracy_test: 0.4894, Duration: 0:00:01.792476
# Epoch 112/200, Train Loss: 3.6013, Test Loss: 510.6431, accuracy_train: 0.9918, accuracy_test: 0.5106, Duration: 0:00:01.764739
# Epoch 113/200, Train Loss: 11.8123, Test Loss: 476.5835, accuracy_train: 0.9898, accuracy_test: 0.5957, Duration: 0:00:01.755075
# Epoch 114/200, Train Loss: 14.4940, Test Loss: 551.4013, accuracy_train: 1.0000, accuracy_test: 0.5957, Duration: 0:00:01.748765
# Epoch 115/200, Train Loss: 4.8966, Test Loss: 564.9803, accuracy_train: 0.9959, accuracy_test: 0.5957, Duration: 0:00:01.781761
# Epoch 116/200, Train Loss: 6.6171, Test Loss: 539.1235, accuracy_train: 0.9939, accuracy_test: 0.5319, Duration: 0:00:01.776229
# Epoch 117/200, Train Loss: 8.2180, Test Loss: 545.6649, accuracy_train: 0.9939, accuracy_test: 0.5319, Duration: 0:00:01.800957
# Epoch 118/200, Train Loss: 6.0354, Test Loss: 537.4602, accuracy_train: 0.9959, accuracy_test: 0.5957, Duration: 0:00:01.774556
# Epoch 119/200, Train Loss: 15.5708, Test Loss: 538.5775, accuracy_train: 1.0000, accuracy_test: 0.5745, Duration: 0:00:01.802449
# Epoch 120/200, Train Loss: 11.7074, Test Loss: 545.7542, accuracy_train: 0.9959, accuracy_test: 0.5957, Duration: 0:00:01.786850
# Epoch 121/200, Train Loss: 8.3843, Test Loss: 528.3786, accuracy_train: 0.9959, accuracy_test: 0.5745, Duration: 0:00:01.882463
# Epoch 122/200, Train Loss: 2.3576, Test Loss: 540.8964, accuracy_train: 0.9959, accuracy_test: 0.5106, Duration: 0:00:01.826904
# Epoch 123/200, Train Loss: 5.8181, Test Loss: 648.8593, accuracy_train: 0.9816, accuracy_test: 0.5957, Duration: 0:00:01.821465
# Epoch 124/200, Train Loss: 7.7414, Test Loss: 647.9764, accuracy_train: 0.9877, accuracy_test: 0.5532, Duration: 0:00:01.774631
# Epoch 125/200, Train Loss: 8.8667, Test Loss: 636.3739, accuracy_train: 0.9939, accuracy_test: 0.5319, Duration: 0:00:01.754741
# Epoch 126/200, Train Loss: 8.4364, Test Loss: 687.5602, accuracy_train: 0.9898, accuracy_test: 0.5106, Duration: 0:00:01.840569
# Epoch 127/200, Train Loss: 7.0518, Test Loss: 725.3425, accuracy_train: 0.9918, accuracy_test: 0.4681, Duration: 0:00:01.783653
# Epoch 128/200, Train Loss: 10.4695, Test Loss: 672.5787, accuracy_train: 0.9980, accuracy_test: 0.4894, Duration: 0:00:01.786578
# Epoch 129/200, Train Loss: 9.1003, Test Loss: 656.6590, accuracy_train: 0.9980, accuracy_test: 0.4681, Duration: 0:00:01.765445
# Epoch 130/200, Train Loss: 10.6264, Test Loss: 658.4362, accuracy_train: 0.9980, accuracy_test: 0.4681, Duration: 0:00:01.796397
# Epoch 131/200, Train Loss: 6.3456, Test Loss: 624.1388, accuracy_train: 0.9877, accuracy_test: 0.4681, Duration: 0:00:01.782391
# Epoch 132/200, Train Loss: 6.0536, Test Loss: 638.0773, accuracy_train: 0.9898, accuracy_test: 0.5106, Duration: 0:00:01.796095
# Epoch 133/200, Train Loss: 10.6595, Test Loss: 706.2804, accuracy_train: 0.9877, accuracy_test: 0.4894, Duration: 0:00:01.805937
# Epoch 134/200, Train Loss: 6.4168, Test Loss: 677.9200, accuracy_train: 0.9898, accuracy_test: 0.5319, Duration: 0:00:01.749916
# Epoch 135/200, Train Loss: 7.6338, Test Loss: 709.9039, accuracy_train: 1.0000, accuracy_test: 0.4468, Duration: 0:00:01.773170
# Epoch 136/200, Train Loss: 5.5446, Test Loss: 670.8976, accuracy_train: 0.9959, accuracy_test: 0.5319, Duration: 0:00:01.765419
# Epoch 137/200, Train Loss: 3.7037, Test Loss: 692.0866, accuracy_train: 1.0000, accuracy_test: 0.4894, Duration: 0:00:01.843170
# Epoch 138/200, Train Loss: 4.6322, Test Loss: 677.8210, accuracy_train: 0.9980, accuracy_test: 0.5745, Duration: 0:00:01.763294
# Epoch 139/200, Train Loss: 4.4977, Test Loss: 603.9894, accuracy_train: 0.9939, accuracy_test: 0.5745, Duration: 0:00:01.780222
# Epoch 140/200, Train Loss: 12.2144, Test Loss: 631.8262, accuracy_train: 0.9877, accuracy_test: 0.5106, Duration: 0:00:01.765470
# Epoch 141/200, Train Loss: 13.4507, Test Loss: 641.8699, accuracy_train: 0.9939, accuracy_test: 0.5106, Duration: 0:00:01.755202
# Epoch 142/200, Train Loss: 8.2678, Test Loss: 762.4249, accuracy_train: 0.9939, accuracy_test: 0.4468, Duration: 0:00:01.780139
# Epoch 143/200, Train Loss: 11.7879, Test Loss: 712.2192, accuracy_train: 0.9918, accuracy_test: 0.4255, Duration: 0:00:01.753216
# Epoch 144/200, Train Loss: 7.8993, Test Loss: 694.7332, accuracy_train: 0.9959, accuracy_test: 0.5106, Duration: 0:00:01.769905
# Epoch 145/200, Train Loss: 4.9587, Test Loss: 743.3237, accuracy_train: 0.9836, accuracy_test: 0.5532, Duration: 0:00:01.804362
# Epoch 146/200, Train Loss: 14.6289, Test Loss: 724.0235, accuracy_train: 0.9918, accuracy_test: 0.5106, Duration: 0:00:01.779229
# Epoch 147/200, Train Loss: 7.2768, Test Loss: 718.9120, accuracy_train: 0.9959, accuracy_test: 0.5106, Duration: 0:00:01.753254
# Epoch 148/200, Train Loss: 16.1273, Test Loss: 684.9355, accuracy_train: 0.9959, accuracy_test: 0.5319, Duration: 0:00:01.776102
# Epoch 149/200, Train Loss: 10.3267, Test Loss: 719.7164, accuracy_train: 0.9959, accuracy_test: 0.5319, Duration: 0:00:01.753576
# Epoch 150/200, Train Loss: 9.3199, Test Loss: 791.1443, accuracy_train: 0.9939, accuracy_test: 0.4468, Duration: 0:00:01.753466
# Epoch 151/200, Train Loss: 11.3936, Test Loss: 718.4216, accuracy_train: 1.0000, accuracy_test: 0.5532, Duration: 0:00:01.838015
# Epoch 152/200, Train Loss: 3.5206, Test Loss: 671.0064, accuracy_train: 0.9959, accuracy_test: 0.5532, Duration: 0:00:01.781074
# Epoch 153/200, Train Loss: 8.7044, Test Loss: 687.8165, accuracy_train: 0.9959, accuracy_test: 0.5957, Duration: 0:00:01.748474
# Epoch 154/200, Train Loss: 3.0221, Test Loss: 700.7336, accuracy_train: 0.9980, accuracy_test: 0.5745, Duration: 0:00:01.783636
# Epoch 155/200, Train Loss: 11.8082, Test Loss: 657.0537, accuracy_train: 0.9939, accuracy_test: 0.5745, Duration: 0:00:01.796714
# Epoch 156/200, Train Loss: 10.1816, Test Loss: 663.5089, accuracy_train: 0.9918, accuracy_test: 0.5106, Duration: 0:00:01.809552
# Epoch 157/200, Train Loss: 9.0114, Test Loss: 678.6651, accuracy_train: 0.9918, accuracy_test: 0.4894, Duration: 0:00:01.796999
# Epoch 158/200, Train Loss: 9.2017, Test Loss: 706.1477, accuracy_train: 0.9939, accuracy_test: 0.5319, Duration: 0:00:01.777757
# Epoch 159/200, Train Loss: 18.3937, Test Loss: 637.0509, accuracy_train: 0.9980, accuracy_test: 0.5532, Duration: 0:00:01.744963
# Epoch 160/200, Train Loss: 2.5696, Test Loss: 682.6544, accuracy_train: 0.9959, accuracy_test: 0.5319, Duration: 0:00:01.806531
# Epoch 161/200, Train Loss: 7.4810, Test Loss: 761.6519, accuracy_train: 0.9959, accuracy_test: 0.5745, Duration: 0:00:01.773143
# Epoch 162/200, Train Loss: 2.6222, Test Loss: 670.2486, accuracy_train: 0.9918, accuracy_test: 0.5106, Duration: 0:00:01.786695
# Epoch 163/200, Train Loss: 7.5924, Test Loss: 741.2566, accuracy_train: 0.9980, accuracy_test: 0.5957, Duration: 0:00:01.788328
# Epoch 164/200, Train Loss: 9.7890, Test Loss: 721.6653, accuracy_train: 0.9980, accuracy_test: 0.5532, Duration: 0:00:01.789868
# Epoch 165/200, Train Loss: 7.1466, Test Loss: 861.0820, accuracy_train: 0.9939, accuracy_test: 0.5745, Duration: 0:00:01.786883
# Epoch 166/200, Train Loss: 17.9850, Test Loss: 984.3897, accuracy_train: 0.9939, accuracy_test: 0.5106, Duration: 0:00:01.746661
# Epoch 167/200, Train Loss: 1.5870, Test Loss: 943.4631, accuracy_train: 0.9918, accuracy_test: 0.5106, Duration: 0:00:01.778890
# Epoch 168/200, Train Loss: 7.3150, Test Loss: 808.2181, accuracy_train: 1.0000, accuracy_test: 0.5745, Duration: 0:00:01.783970
# Epoch 169/200, Train Loss: 5.8176, Test Loss: 747.1774, accuracy_train: 1.0000, accuracy_test: 0.4894, Duration: 0:00:01.784688
# Epoch 170/200, Train Loss: 5.4036, Test Loss: 745.0295, accuracy_train: 0.9959, accuracy_test: 0.5532, Duration: 0:00:01.775699
# Epoch 171/200, Train Loss: 10.6984, Test Loss: 834.7533, accuracy_train: 0.9980, accuracy_test: 0.5106, Duration: 0:00:01.765347
# Epoch 172/200, Train Loss: 7.3607, Test Loss: 654.8670, accuracy_train: 0.9939, accuracy_test: 0.5745, Duration: 0:00:01.785239
# Epoch 173/200, Train Loss: 4.5791, Test Loss: 679.9150, accuracy_train: 0.9939, accuracy_test: 0.5957, Duration: 0:00:01.768599
# Epoch 174/200, Train Loss: 10.3181, Test Loss: 710.7298, accuracy_train: 0.9959, accuracy_test: 0.6383, Duration: 0:00:01.852418
# Epoch 175/200, Train Loss: 7.4149, Test Loss: 713.7057, accuracy_train: 0.9980, accuracy_test: 0.5745, Duration: 0:00:01.771004
# Epoch 176/200, Train Loss: 6.7783, Test Loss: 715.0269, accuracy_train: 0.9959, accuracy_test: 0.5532, Duration: 0:00:01.777040
# Epoch 177/200, Train Loss: 6.3330, Test Loss: 752.1756, accuracy_train: 0.9980, accuracy_test: 0.4894, Duration: 0:00:01.750178
# Epoch 178/200, Train Loss: 3.4319, Test Loss: 778.9193, accuracy_train: 0.9939, accuracy_test: 0.5319, Duration: 0:00:01.785431
# Epoch 179/200, Train Loss: 8.4042, Test Loss: 794.9504, accuracy_train: 0.9918, accuracy_test: 0.4894, Duration: 0:00:01.788770
# Epoch 180/200, Train Loss: 5.3800, Test Loss: 907.0832, accuracy_train: 0.9857, accuracy_test: 0.4681, Duration: 0:00:01.782459
# Epoch 181/200, Train Loss: 10.4955, Test Loss: 758.2670, accuracy_train: 0.9980, accuracy_test: 0.4468, Duration: 0:00:01.770408
# Epoch 182/200, Train Loss: 5.8211, Test Loss: 984.7154, accuracy_train: 0.9816, accuracy_test: 0.4681, Duration: 0:00:01.746945
# Epoch 183/200, Train Loss: 11.9248, Test Loss: 846.4211, accuracy_train: 0.9959, accuracy_test: 0.4255, Duration: 0:00:01.779110
# Epoch 184/200, Train Loss: 5.1664, Test Loss: 909.1639, accuracy_train: 1.0000, accuracy_test: 0.4468, Duration: 0:00:01.794699
# Epoch 185/200, Train Loss: 5.5420, Test Loss: 885.2637, accuracy_train: 0.9898, accuracy_test: 0.4255, Duration: 0:00:01.779550
# Epoch 186/200, Train Loss: 13.2949, Test Loss: 917.5534, accuracy_train: 0.9939, accuracy_test: 0.4255, Duration: 0:00:01.760277
# Epoch 187/200, Train Loss: 1.7947, Test Loss: 993.7988, accuracy_train: 0.9877, accuracy_test: 0.4255, Duration: 0:00:01.767828
# Epoch 188/200, Train Loss: 10.1571, Test Loss: 914.5880, accuracy_train: 0.9959, accuracy_test: 0.5532, Duration: 0:00:01.774343
# Epoch 189/200, Train Loss: 17.2703, Test Loss: 869.3476, accuracy_train: 0.9980, accuracy_test: 0.4681, Duration: 0:00:01.777389
# Epoch 190/200, Train Loss: 7.8460, Test Loss: 913.6316, accuracy_train: 0.9959, accuracy_test: 0.4894, Duration: 0:00:01.772753
# Epoch 191/200, Train Loss: 4.1830, Test Loss: 939.7886, accuracy_train: 0.9980, accuracy_test: 0.5106, Duration: 0:00:01.809139
# Epoch 192/200, Train Loss: 4.5322, Test Loss: 912.0597, accuracy_train: 1.0000, accuracy_test: 0.4894, Duration: 0:00:01.789364
# Epoch 193/200, Train Loss: 5.8900, Test Loss: 878.7115, accuracy_train: 0.9980, accuracy_test: 0.5319, Duration: 0:00:01.851371
# Epoch 194/200, Train Loss: 5.0789, Test Loss: 849.6548, accuracy_train: 0.9980, accuracy_test: 0.4681, Duration: 0:00:01.764528
# Epoch 195/200, Train Loss: 2.2903, Test Loss: 791.1431, accuracy_train: 0.9980, accuracy_test: 0.4468, Duration: 0:00:01.818483
# Epoch 196/200, Train Loss: 10.6599, Test Loss: 878.6371, accuracy_train: 1.0000, accuracy_test: 0.4468, Duration: 0:00:01.780205
# Epoch 197/200, Train Loss: 3.9408, Test Loss: 835.8673, accuracy_train: 1.0000, accuracy_test: 0.4894, Duration: 0:00:01.804993
# Epoch 198/200, Train Loss: 2.3578, Test Loss: 857.3063, accuracy_train: 1.0000, accuracy_test: 0.5532, Duration: 0:00:01.775595
# Epoch 199/200, Train Loss: 7.2668, Test Loss: 783.3689, accuracy_train: 0.9939, accuracy_test: 0.5319, Duration: 0:00:01.797543
# Epoch 200/200, Train Loss: 15.8687, Test Loss: 859.9995, accuracy_train: 0.9959, accuracy_test: 0.4894, Duration: 0:00:01.777470

# %% [markdown]
# # Results with Frame-based Attention Mechanism (Best 65.96)

# %%
train_losses, test_losses = batch_gd(model, criterion, optimizer, train_loader, test_loader, epochs=200)
# Out:
# Epoch 1/200, Train Loss: 1200.6798, Test Loss: 796.1382, accuracy_train: 0.3463, accuracy_test: 0.2553, Duration: 0:00:03.239980
# Epoch 2/200, Train Loss: 698.3785, Test Loss: 577.1768, accuracy_train: 0.3525, accuracy_test: 0.3617, Duration: 0:00:01.826536
# Epoch 3/200, Train Loss: 580.9515, Test Loss: 533.0606, accuracy_train: 0.4037, accuracy_test: 0.2766, Duration: 0:00:01.806217
# Epoch 4/200, Train Loss: 404.0277, Test Loss: 402.9656, accuracy_train: 0.5451, accuracy_test: 0.4255, Duration: 0:00:01.816111
# Epoch 5/200, Train Loss: 321.5694, Test Loss: 527.5856, accuracy_train: 0.5717, accuracy_test: 0.3617, Duration: 0:00:01.820112
# Epoch 6/200, Train Loss: 366.0500, Test Loss: 416.2723, accuracy_train: 0.6455, accuracy_test: 0.4468, Duration: 0:00:01.815130
# Epoch 7/200, Train Loss: 306.3182, Test Loss: 419.3286, accuracy_train: 0.5738, accuracy_test: 0.4043, Duration: 0:00:01.799698
# Epoch 8/200, Train Loss: 273.0719, Test Loss: 420.1214, accuracy_train: 0.5840, accuracy_test: 0.3830, Duration: 0:00:01.797569
# Epoch 9/200, Train Loss: 337.5058, Test Loss: 366.2900, accuracy_train: 0.5512, accuracy_test: 0.4043, Duration: 0:00:01.799632
# Epoch 10/200, Train Loss: 208.5229, Test Loss: 333.2296, accuracy_train: 0.6270, accuracy_test: 0.4043, Duration: 0:00:01.812410
# Epoch 11/200, Train Loss: 213.2748, Test Loss: 268.0014, accuracy_train: 0.6742, accuracy_test: 0.4468, Duration: 0:00:01.819180
# Epoch 12/200, Train Loss: 215.8496, Test Loss: 247.7794, accuracy_train: 0.6762, accuracy_test: 0.5319, Duration: 0:00:01.831755
# Epoch 13/200, Train Loss: 172.8224, Test Loss: 260.3723, accuracy_train: 0.6742, accuracy_test: 0.4894, Duration: 0:00:01.800693
# Epoch 14/200, Train Loss: 192.5291, Test Loss: 288.3857, accuracy_train: 0.6721, accuracy_test: 0.4043, Duration: 0:00:01.832787
# Epoch 15/200, Train Loss: 150.9657, Test Loss: 196.8450, accuracy_train: 0.6885, accuracy_test: 0.4468, Duration: 0:00:01.841625
# Epoch 16/200, Train Loss: 207.0833, Test Loss: 218.6338, accuracy_train: 0.7316, accuracy_test: 0.4468, Duration: 0:00:01.844133
# Epoch 17/200, Train Loss: 166.6103, Test Loss: 208.5362, accuracy_train: 0.6967, accuracy_test: 0.4681, Duration: 0:00:01.839223
# Epoch 18/200, Train Loss: 117.9384, Test Loss: 333.8966, accuracy_train: 0.7357, accuracy_test: 0.4255, Duration: 0:00:01.827540
# Epoch 19/200, Train Loss: 235.7529, Test Loss: 207.2063, accuracy_train: 0.5963, accuracy_test: 0.4894, Duration: 0:00:01.814567
# Epoch 20/200, Train Loss: 166.0751, Test Loss: 237.6391, accuracy_train: 0.6475, accuracy_test: 0.5745, Duration: 0:00:01.832654
# Epoch 21/200, Train Loss: 139.4840, Test Loss: 302.1377, accuracy_train: 0.6680, accuracy_test: 0.4255, Duration: 0:00:01.803311
# Epoch 22/200, Train Loss: 132.8878, Test Loss: 292.2549, accuracy_train: 0.7295, accuracy_test: 0.4894, Duration: 0:00:01.813797
# Epoch 23/200, Train Loss: 123.7187, Test Loss: 273.8456, accuracy_train: 0.6332, accuracy_test: 0.4043, Duration: 0:00:01.817093
# Epoch 24/200, Train Loss: 98.5721, Test Loss: 331.6703, accuracy_train: 0.6783, accuracy_test: 0.3617, Duration: 0:00:01.809476
# Epoch 25/200, Train Loss: 121.6750, Test Loss: 279.3198, accuracy_train: 0.7295, accuracy_test: 0.4894, Duration: 0:00:01.812276
# Epoch 26/200, Train Loss: 158.3947, Test Loss: 353.4143, accuracy_train: 0.7377, accuracy_test: 0.4468, Duration: 0:00:01.826686
# Epoch 27/200, Train Loss: 136.6938, Test Loss: 284.8101, accuracy_train: 0.7480, accuracy_test: 0.3404, Duration: 0:00:01.865553
# Epoch 28/200, Train Loss: 137.4700, Test Loss: 285.4355, accuracy_train: 0.7684, accuracy_test: 0.2766, Duration: 0:00:01.840513
# Epoch 29/200, Train Loss: 97.3290, Test Loss: 316.2459, accuracy_train: 0.7992, accuracy_test: 0.4255, Duration: 0:00:01.802687
# Epoch 30/200, Train Loss: 118.6708, Test Loss: 316.6972, accuracy_train: 0.7029, accuracy_test: 0.4255, Duration: 0:00:01.787970
# Epoch 31/200, Train Loss: 149.4560, Test Loss: 257.7991, accuracy_train: 0.7725, accuracy_test: 0.4894, Duration: 0:00:01.786746
# Epoch 32/200, Train Loss: 93.1246, Test Loss: 283.0855, accuracy_train: 0.7889, accuracy_test: 0.4468, Duration: 0:00:01.808351
# Epoch 33/200, Train Loss: 92.9992, Test Loss: 308.0924, accuracy_train: 0.7213, accuracy_test: 0.4255, Duration: 0:00:01.834020
# Epoch 34/200, Train Loss: 76.9646, Test Loss: 338.5091, accuracy_train: 0.8238, accuracy_test: 0.4468, Duration: 0:00:01.837298
# Epoch 35/200, Train Loss: 90.4280, Test Loss: 615.4500, accuracy_train: 0.7561, accuracy_test: 0.5106, Duration: 0:00:01.819150
# Epoch 36/200, Train Loss: 87.8286, Test Loss: 596.0235, accuracy_train: 0.7602, accuracy_test: 0.4043, Duration: 0:00:01.792448
# Epoch 37/200, Train Loss: 98.4082, Test Loss: 461.1551, accuracy_train: 0.7869, accuracy_test: 0.4255, Duration: 0:00:01.805207
# Epoch 38/200, Train Loss: 100.2600, Test Loss: 325.4302, accuracy_train: 0.7541, accuracy_test: 0.4043, Duration: 0:00:01.844944
# Epoch 39/200, Train Loss: 87.4026, Test Loss: 309.1236, accuracy_train: 0.7561, accuracy_test: 0.4255, Duration: 0:00:01.818344
# Epoch 40/200, Train Loss: 158.7029, Test Loss: 199.2482, accuracy_train: 0.7623, accuracy_test: 0.4255, Duration: 0:00:01.810756
# Epoch 41/200, Train Loss: 100.1424, Test Loss: 214.8592, accuracy_train: 0.7828, accuracy_test: 0.4043, Duration: 0:00:01.807828
# Epoch 42/200, Train Loss: 81.9744, Test Loss: 227.1612, accuracy_train: 0.8361, accuracy_test: 0.4894, Duration: 0:00:01.819848
# Epoch 43/200, Train Loss: 67.1893, Test Loss: 198.5255, accuracy_train: 0.8279, accuracy_test: 0.5532, Duration: 0:00:01.812113
# Epoch 44/200, Train Loss: 81.7103, Test Loss: 252.7925, accuracy_train: 0.8340, accuracy_test: 0.5106, Duration: 0:00:01.817176
# Epoch 45/200, Train Loss: 72.1612, Test Loss: 286.6599, accuracy_train: 0.7602, accuracy_test: 0.5106, Duration: 0:00:01.798341
# Epoch 46/200, Train Loss: 78.2027, Test Loss: 268.6099, accuracy_train: 0.8012, accuracy_test: 0.5106, Duration: 0:00:01.838483
# Epoch 47/200, Train Loss: 68.2616, Test Loss: 280.6377, accuracy_train: 0.8094, accuracy_test: 0.5319, Duration: 0:00:01.816366
# Epoch 48/200, Train Loss: 76.7592, Test Loss: 140.0295, accuracy_train: 0.8012, accuracy_test: 0.5957, Duration: 0:00:01.809326
# Epoch 49/200, Train Loss: 121.3553, Test Loss: 123.2098, accuracy_train: 0.8320, accuracy_test: 0.5532, Duration: 0:00:01.805994
# Epoch 50/200, Train Loss: 73.7348, Test Loss: 159.2617, accuracy_train: 0.8012, accuracy_test: 0.6170, Duration: 0:00:01.861395
# Epoch 51/200, Train Loss: 58.0172, Test Loss: 256.9240, accuracy_train: 0.7766, accuracy_test: 0.5319, Duration: 0:00:01.865450
# Epoch 52/200, Train Loss: 103.0139, Test Loss: 216.0640, accuracy_train: 0.7643, accuracy_test: 0.4894, Duration: 0:00:01.824625
# Epoch 53/200, Train Loss: 66.5031, Test Loss: 233.7708, accuracy_train: 0.8361, accuracy_test: 0.5532, Duration: 0:00:01.825491
# Epoch 54/200, Train Loss: 87.7303, Test Loss: 207.8901, accuracy_train: 0.8422, accuracy_test: 0.6170, Duration: 0:00:01.821657
# Epoch 55/200, Train Loss: 56.0038, Test Loss: 205.9597, accuracy_train: 0.8258, accuracy_test: 0.5745, Duration: 0:00:01.786584
# Epoch 56/200, Train Loss: 60.6272, Test Loss: 219.5996, accuracy_train: 0.8361, accuracy_test: 0.5957, Duration: 0:00:01.807008
# Epoch 57/200, Train Loss: 67.5802, Test Loss: 181.9503, accuracy_train: 0.8709, accuracy_test: 0.6170, Duration: 0:00:01.801977
# Epoch 58/200, Train Loss: 83.8344, Test Loss: 253.3208, accuracy_train: 0.8299, accuracy_test: 0.5319, Duration: 0:00:01.810012
# Epoch 59/200, Train Loss: 106.6168, Test Loss: 222.3307, accuracy_train: 0.8074, accuracy_test: 0.4468, Duration: 0:00:01.801719
# Epoch 60/200, Train Loss: 61.9947, Test Loss: 238.2084, accuracy_train: 0.8381, accuracy_test: 0.5319, Duration: 0:00:01.802943
# Epoch 61/200, Train Loss: 77.8583, Test Loss: 214.4440, accuracy_train: 0.8463, accuracy_test: 0.5106, Duration: 0:00:01.795810
# Epoch 62/200, Train Loss: 57.6370, Test Loss: 246.7493, accuracy_train: 0.8402, accuracy_test: 0.3830, Duration: 0:00:01.804156
# Epoch 63/200, Train Loss: 66.2739, Test Loss: 246.8416, accuracy_train: 0.8135, accuracy_test: 0.5106, Duration: 0:00:01.831899
# Epoch 64/200, Train Loss: 116.0361, Test Loss: 257.0807, accuracy_train: 0.7664, accuracy_test: 0.4894, Duration: 0:00:01.839200
# Epoch 65/200, Train Loss: 88.3504, Test Loss: 267.5284, accuracy_train: 0.8279, accuracy_test: 0.4681, Duration: 0:00:01.802397
# Epoch 66/200, Train Loss: 78.9974, Test Loss: 255.9265, accuracy_train: 0.8873, accuracy_test: 0.4255, Duration: 0:00:01.825186
# Epoch 67/200, Train Loss: 72.7466, Test Loss: 247.9008, accuracy_train: 0.8955, accuracy_test: 0.5319, Duration: 0:00:01.830941
# Epoch 68/200, Train Loss: 50.8817, Test Loss: 272.6492, accuracy_train: 0.8893, accuracy_test: 0.4255, Duration: 0:00:01.840772
# Epoch 69/200, Train Loss: 67.6536, Test Loss: 232.0944, accuracy_train: 0.8811, accuracy_test: 0.5319, Duration: 0:00:01.828858
# Epoch 70/200, Train Loss: 56.2754, Test Loss: 237.4410, accuracy_train: 0.8279, accuracy_test: 0.3191, Duration: 0:00:01.851347
# Epoch 71/200, Train Loss: 61.5060, Test Loss: 277.8164, accuracy_train: 0.9098, accuracy_test: 0.4681, Duration: 0:00:01.858781
# Epoch 72/200, Train Loss: 30.4651, Test Loss: 223.1046, accuracy_train: 0.9078, accuracy_test: 0.4043, Duration: 0:00:01.823155
# Epoch 73/200, Train Loss: 52.4246, Test Loss: 187.4914, accuracy_train: 0.8709, accuracy_test: 0.4894, Duration: 0:00:01.805287
# Epoch 74/200, Train Loss: 52.4591, Test Loss: 228.7063, accuracy_train: 0.8934, accuracy_test: 0.5106, Duration: 0:00:01.845282
# Epoch 75/200, Train Loss: 57.5050, Test Loss: 217.2835, accuracy_train: 0.8955, accuracy_test: 0.5319, Duration: 0:00:01.814557
# Epoch 76/200, Train Loss: 76.6194, Test Loss: 222.2929, accuracy_train: 0.8709, accuracy_test: 0.4894, Duration: 0:00:01.817509
# Epoch 77/200, Train Loss: 69.8207, Test Loss: 220.8855, accuracy_train: 0.8873, accuracy_test: 0.5319, Duration: 0:00:01.834840
# Epoch 78/200, Train Loss: 68.3424, Test Loss: 272.2367, accuracy_train: 0.8852, accuracy_test: 0.4681, Duration: 0:00:01.788497
# Epoch 79/200, Train Loss: 63.4446, Test Loss: 244.5591, accuracy_train: 0.8730, accuracy_test: 0.5319, Duration: 0:00:01.824252
# Epoch 80/200, Train Loss: 43.3412, Test Loss: 231.4123, accuracy_train: 0.8934, accuracy_test: 0.4255, Duration: 0:00:01.825396
# Epoch 81/200, Train Loss: 57.2901, Test Loss: 205.0380, accuracy_train: 0.8709, accuracy_test: 0.5106, Duration: 0:00:01.836328
# Epoch 82/200, Train Loss: 58.8476, Test Loss: 241.6711, accuracy_train: 0.8709, accuracy_test: 0.4681, Duration: 0:00:01.802622
# Epoch 83/200, Train Loss: 45.8243, Test Loss: 182.0997, accuracy_train: 0.9201, accuracy_test: 0.4468, Duration: 0:00:01.825213
# Epoch 84/200, Train Loss: 30.9663, Test Loss: 233.5245, accuracy_train: 0.9262, accuracy_test: 0.4894, Duration: 0:00:01.810356
# Epoch 85/200, Train Loss: 56.0849, Test Loss: 197.0780, accuracy_train: 0.9098, accuracy_test: 0.4894, Duration: 0:00:01.819721
# Epoch 86/200, Train Loss: 46.5211, Test Loss: 145.9867, accuracy_train: 0.9221, accuracy_test: 0.5106, Duration: 0:00:01.827842
# Epoch 87/200, Train Loss: 49.6088, Test Loss: 227.8119, accuracy_train: 0.8996, accuracy_test: 0.4894, Duration: 0:00:01.807983
# Epoch 88/200, Train Loss: 51.3241, Test Loss: 202.0003, accuracy_train: 0.9016, accuracy_test: 0.5532, Duration: 0:00:01.801621
# Epoch 89/200, Train Loss: 51.3294, Test Loss: 262.4980, accuracy_train: 0.9262, accuracy_test: 0.5106, Duration: 0:00:01.794924
# Epoch 90/200, Train Loss: 51.4746, Test Loss: 195.1942, accuracy_train: 0.9262, accuracy_test: 0.5957, Duration: 0:00:01.813372
# Epoch 91/200, Train Loss: 70.4118, Test Loss: 200.8524, accuracy_train: 0.9221, accuracy_test: 0.5106, Duration: 0:00:01.815833
# Epoch 92/200, Train Loss: 32.3896, Test Loss: 352.7842, accuracy_train: 0.9180, accuracy_test: 0.5745, Duration: 0:00:01.794589
# Epoch 93/200, Train Loss: 44.4747, Test Loss: 289.6975, accuracy_train: 0.8955, accuracy_test: 0.5745, Duration: 0:00:01.853847
# Epoch 94/200, Train Loss: 36.9111, Test Loss: 240.7683, accuracy_train: 0.9201, accuracy_test: 0.6170, Duration: 0:00:01.828075
# Epoch 95/200, Train Loss: 60.2829, Test Loss: 300.1106, accuracy_train: 0.9016, accuracy_test: 0.5532, Duration: 0:00:01.811818
# Epoch 96/200, Train Loss: 49.5917, Test Loss: 274.2653, accuracy_train: 0.9283, accuracy_test: 0.5532, Duration: 0:00:01.810498
# Epoch 97/200, Train Loss: 45.0309, Test Loss: 276.8728, accuracy_train: 0.9016, accuracy_test: 0.4043, Duration: 0:00:01.805525
# Epoch 98/200, Train Loss: 53.3562, Test Loss: 247.0675, accuracy_train: 0.8730, accuracy_test: 0.4894, Duration: 0:00:01.859484
# Epoch 99/200, Train Loss: 39.0218, Test Loss: 282.4172, accuracy_train: 0.9242, accuracy_test: 0.4255, Duration: 0:00:01.871663
# Epoch 100/200, Train Loss: 60.8154, Test Loss: 351.9262, accuracy_train: 0.9180, accuracy_test: 0.5319, Duration: 0:00:01.814926
# Epoch 101/200, Train Loss: 60.9965, Test Loss: 312.3217, accuracy_train: 0.9324, accuracy_test: 0.4255, Duration: 0:00:01.869446
# Epoch 102/200, Train Loss: 46.0159, Test Loss: 313.1392, accuracy_train: 0.9262, accuracy_test: 0.5319, Duration: 0:00:01.920980
# Epoch 103/200, Train Loss: 48.9176, Test Loss: 306.6956, accuracy_train: 0.9303, accuracy_test: 0.5106, Duration: 0:00:01.889139
# Epoch 104/200, Train Loss: 46.6459, Test Loss: 302.2438, accuracy_train: 0.9447, accuracy_test: 0.4894, Duration: 0:00:01.821286
# Epoch 105/200, Train Loss: 44.0671, Test Loss: 336.0057, accuracy_train: 0.9016, accuracy_test: 0.4681, Duration: 0:00:01.839374
# Epoch 106/200, Train Loss: 36.7973, Test Loss: 279.6007, accuracy_train: 0.9242, accuracy_test: 0.6596, Duration: 0:00:01.879621
# Epoch 107/200, Train Loss: 50.5148, Test Loss: 327.9991, accuracy_train: 0.9385, accuracy_test: 0.6170, Duration: 0:00:01.835751
# Epoch 108/200, Train Loss: 33.9194, Test Loss: 257.0575, accuracy_train: 0.9303, accuracy_test: 0.6383, Duration: 0:00:01.815589
# Epoch 109/200, Train Loss: 50.4825, Test Loss: 312.1565, accuracy_train: 0.9488, accuracy_test: 0.6596, Duration: 0:00:01.828903
# Epoch 110/200, Train Loss: 60.9364, Test Loss: 351.5697, accuracy_train: 0.9303, accuracy_test: 0.5106, Duration: 0:00:01.808618
# Epoch 111/200, Train Loss: 40.8567, Test Loss: 327.5350, accuracy_train: 0.9385, accuracy_test: 0.6170, Duration: 0:00:01.812286
# Epoch 112/200, Train Loss: 48.2950, Test Loss: 321.1208, accuracy_train: 0.9406, accuracy_test: 0.5532, Duration: 0:00:01.808770
# Epoch 113/200, Train Loss: 53.5520, Test Loss: 319.2909, accuracy_train: 0.9303, accuracy_test: 0.5957, Duration: 0:00:01.829668
# Epoch 114/200, Train Loss: 53.0614, Test Loss: 277.5711, accuracy_train: 0.9344, accuracy_test: 0.5957, Duration: 0:00:01.817609
# Epoch 115/200, Train Loss: 40.0090, Test Loss: 361.7664, accuracy_train: 0.9283, accuracy_test: 0.5319, Duration: 0:00:01.800727
# Epoch 116/200, Train Loss: 33.9643, Test Loss: 409.5752, accuracy_train: 0.9590, accuracy_test: 0.5532, Duration: 0:00:01.807155
# Epoch 117/200, Train Loss: 23.4331, Test Loss: 358.8137, accuracy_train: 0.9693, accuracy_test: 0.5532, Duration: 0:00:01.843418
# Epoch 118/200, Train Loss: 50.5412, Test Loss: 294.5671, accuracy_train: 0.9693, accuracy_test: 0.5957, Duration: 0:00:01.854994
# Epoch 119/200, Train Loss: 18.3593, Test Loss: 343.6135, accuracy_train: 0.9713, accuracy_test: 0.6170, Duration: 0:00:01.853520
# Epoch 120/200, Train Loss: 25.3763, Test Loss: 320.7453, accuracy_train: 0.9590, accuracy_test: 0.6170, Duration: 0:00:01.795163
# Epoch 121/200, Train Loss: 27.7446, Test Loss: 352.9511, accuracy_train: 0.9693, accuracy_test: 0.5745, Duration: 0:00:01.883216
# Epoch 122/200, Train Loss: 36.6198, Test Loss: 276.6954, accuracy_train: 0.9570, accuracy_test: 0.5745, Duration: 0:00:01.894482
# Epoch 123/200, Train Loss: 39.5438, Test Loss: 325.5102, accuracy_train: 0.9611, accuracy_test: 0.5319, Duration: 0:00:01.875371
# Epoch 124/200, Train Loss: 29.1151, Test Loss: 251.4807, accuracy_train: 0.9734, accuracy_test: 0.5957, Duration: 0:00:01.900197
# Epoch 125/200, Train Loss: 32.2672, Test Loss: 285.4354, accuracy_train: 0.9529, accuracy_test: 0.6596, Duration: 0:00:01.831550
# Epoch 126/200, Train Loss: 30.8750, Test Loss: 430.0405, accuracy_train: 0.9590, accuracy_test: 0.5745, Duration: 0:00:01.889448
# Epoch 127/200, Train Loss: 29.4070, Test Loss: 504.9799, accuracy_train: 0.9508, accuracy_test: 0.5532, Duration: 0:00:01.872842
# Epoch 128/200, Train Loss: 27.9144, Test Loss: 358.4941, accuracy_train: 0.9754, accuracy_test: 0.6170, Duration: 0:00:01.824738
# Epoch 129/200, Train Loss: 24.9179, Test Loss: 470.7420, accuracy_train: 0.9467, accuracy_test: 0.5319, Duration: 0:00:01.854872
# Epoch 130/200, Train Loss: 48.2238, Test Loss: 409.9907, accuracy_train: 0.9775, accuracy_test: 0.5745, Duration: 0:00:01.890791
# Epoch 131/200, Train Loss: 36.5274, Test Loss: 423.0854, accuracy_train: 0.9365, accuracy_test: 0.5745, Duration: 0:00:01.795860
# Epoch 132/200, Train Loss: 38.8179, Test Loss: 469.5570, accuracy_train: 0.9652, accuracy_test: 0.5532, Duration: 0:00:01.814825
# Epoch 133/200, Train Loss: 55.9344, Test Loss: 390.8126, accuracy_train: 0.9447, accuracy_test: 0.5319, Duration: 0:00:01.820349
# Epoch 134/200, Train Loss: 29.6777, Test Loss: 415.2697, accuracy_train: 0.9775, accuracy_test: 0.5319, Duration: 0:00:01.850363
# Epoch 135/200, Train Loss: 28.1013, Test Loss: 443.0944, accuracy_train: 0.9488, accuracy_test: 0.4681, Duration: 0:00:01.881061
# Epoch 136/200, Train Loss: 44.1301, Test Loss: 547.9952, accuracy_train: 0.9467, accuracy_test: 0.5106, Duration: 0:00:01.810285
# Epoch 137/200, Train Loss: 38.9363, Test Loss: 545.1090, accuracy_train: 0.9672, accuracy_test: 0.5319, Duration: 0:00:01.831403
# Epoch 138/200, Train Loss: 21.2312, Test Loss: 452.5571, accuracy_train: 0.9590, accuracy_test: 0.5745, Duration: 0:00:01.806254
# Epoch 139/200, Train Loss: 40.6280, Test Loss: 551.3447, accuracy_train: 0.9508, accuracy_test: 0.5532, Duration: 0:00:01.802451
# Epoch 140/200, Train Loss: 33.5348, Test Loss: 522.6505, accuracy_train: 0.9488, accuracy_test: 0.5745, Duration: 0:00:01.883998
# Epoch 141/200, Train Loss: 47.1077, Test Loss: 575.6618, accuracy_train: 0.9488, accuracy_test: 0.4894, Duration: 0:00:01.831635
# Epoch 142/200, Train Loss: 28.2435, Test Loss: 648.0975, accuracy_train: 0.9754, accuracy_test: 0.5745, Duration: 0:00:01.884674
# Epoch 143/200, Train Loss: 27.5002, Test Loss: 603.4044, accuracy_train: 0.9529, accuracy_test: 0.4681, Duration: 0:00:01.810157
# Epoch 144/200, Train Loss: 43.0640, Test Loss: 516.7116, accuracy_train: 0.9590, accuracy_test: 0.5319, Duration: 0:00:01.855558
# Epoch 145/200, Train Loss: 62.0179, Test Loss: 548.7406, accuracy_train: 0.9672, accuracy_test: 0.5745, Duration: 0:00:01.870382
# Epoch 146/200, Train Loss: 28.5103, Test Loss: 593.6750, accuracy_train: 0.9693, accuracy_test: 0.5532, Duration: 0:00:01.851238
# Epoch 147/200, Train Loss: 17.8364, Test Loss: 484.8517, accuracy_train: 0.9672, accuracy_test: 0.5106, Duration: 0:00:01.800382
# Epoch 148/200, Train Loss: 30.0737, Test Loss: 458.6598, accuracy_train: 0.9693, accuracy_test: 0.4681, Duration: 0:00:01.790525
# Epoch 149/200, Train Loss: 41.2835, Test Loss: 435.0104, accuracy_train: 0.9652, accuracy_test: 0.5532, Duration: 0:00:01.840633
# Epoch 150/200, Train Loss: 44.0312, Test Loss: 324.8170, accuracy_train: 0.9570, accuracy_test: 0.5532, Duration: 0:00:01.811058
# Epoch 151/200, Train Loss: 49.1342, Test Loss: 596.4811, accuracy_train: 0.9488, accuracy_test: 0.4894, Duration: 0:00:01.834497
# Epoch 152/200, Train Loss: 61.1145, Test Loss: 603.7459, accuracy_train: 0.9529, accuracy_test: 0.5106, Duration: 0:00:01.836864
# Epoch 153/200, Train Loss: 44.5272, Test Loss: 497.1849, accuracy_train: 0.9385, accuracy_test: 0.5745, Duration: 0:00:01.846098
# Epoch 154/200, Train Loss: 38.7175, Test Loss: 519.6006, accuracy_train: 0.9775, accuracy_test: 0.5106, Duration: 0:00:01.825530
# Epoch 155/200, Train Loss: 49.3571, Test Loss: 513.5417, accuracy_train: 0.9570, accuracy_test: 0.5319, Duration: 0:00:01.818865
# Epoch 156/200, Train Loss: 40.2264, Test Loss: 455.3162, accuracy_train: 0.9713, accuracy_test: 0.5106, Duration: 0:00:01.814637
# Epoch 157/200, Train Loss: 21.6289, Test Loss: 475.8436, accuracy_train: 0.9631, accuracy_test: 0.5319, Duration: 0:00:01.807678
# Epoch 158/200, Train Loss: 22.8198, Test Loss: 625.7303, accuracy_train: 0.9631, accuracy_test: 0.4894, Duration: 0:00:01.825629
# Epoch 159/200, Train Loss: 33.1269, Test Loss: 645.5817, accuracy_train: 0.9549, accuracy_test: 0.4681, Duration: 0:00:01.835496
# Epoch 160/200, Train Loss: 34.4502, Test Loss: 604.0258, accuracy_train: 0.9570, accuracy_test: 0.4681, Duration: 0:00:01.821594
# Epoch 161/200, Train Loss: 37.8159, Test Loss: 565.7115, accuracy_train: 0.9672, accuracy_test: 0.5532, Duration: 0:00:01.848979
# Epoch 162/200, Train Loss: 33.9706, Test Loss: 577.6262, accuracy_train: 0.9795, accuracy_test: 0.4894, Duration: 0:00:01.807457
# Epoch 163/200, Train Loss: 45.6176, Test Loss: 608.4155, accuracy_train: 0.9467, accuracy_test: 0.4894, Duration: 0:00:01.823188
# Epoch 164/200, Train Loss: 45.7748, Test Loss: 664.6596, accuracy_train: 0.9406, accuracy_test: 0.4681, Duration: 0:00:01.855643
# Epoch 165/200, Train Loss: 49.7228, Test Loss: 599.0131, accuracy_train: 0.9672, accuracy_test: 0.5319, Duration: 0:00:01.845741
# Epoch 166/200, Train Loss: 23.7689, Test Loss: 553.5854, accuracy_train: 0.9734, accuracy_test: 0.5106, Duration: 0:00:01.812982
# Epoch 167/200, Train Loss: 44.4396, Test Loss: 488.9549, accuracy_train: 0.9672, accuracy_test: 0.5745, Duration: 0:00:01.829116
# Epoch 168/200, Train Loss: 30.9140, Test Loss: 537.9643, accuracy_train: 0.9734, accuracy_test: 0.5106, Duration: 0:00:01.827413
# Epoch 169/200, Train Loss: 20.6166, Test Loss: 519.6552, accuracy_train: 0.9570, accuracy_test: 0.5745, Duration: 0:00:01.844963
# Epoch 170/200, Train Loss: 41.5818, Test Loss: 638.9743, accuracy_train: 0.9631, accuracy_test: 0.5319, Duration: 0:00:01.837074
# Epoch 171/200, Train Loss: 43.9559, Test Loss: 722.5701, accuracy_train: 0.9508, accuracy_test: 0.4043, Duration: 0:00:01.847170
# Epoch 172/200, Train Loss: 53.8214, Test Loss: 629.6487, accuracy_train: 0.9734, accuracy_test: 0.4255, Duration: 0:00:01.783951
# Epoch 173/200, Train Loss: 20.0033, Test Loss: 576.0256, accuracy_train: 0.9939, accuracy_test: 0.4681, Duration: 0:00:01.809656
# Epoch 174/200, Train Loss: 18.3383, Test Loss: 535.5564, accuracy_train: 0.9836, accuracy_test: 0.5106, Duration: 0:00:01.862221
# Epoch 175/200, Train Loss: 16.9120, Test Loss: 483.2680, accuracy_train: 0.9795, accuracy_test: 0.5745, Duration: 0:00:01.824478
# Epoch 176/200, Train Loss: 31.6681, Test Loss: 451.8433, accuracy_train: 0.9877, accuracy_test: 0.5319, Duration: 0:00:01.883398
# Epoch 177/200, Train Loss: 21.3471, Test Loss: 541.0290, accuracy_train: 0.9877, accuracy_test: 0.4894, Duration: 0:00:01.861691
# Epoch 178/200, Train Loss: 27.9423, Test Loss: 507.9201, accuracy_train: 0.9754, accuracy_test: 0.5745, Duration: 0:00:01.886886
# Epoch 179/200, Train Loss: 35.7037, Test Loss: 571.0484, accuracy_train: 0.9549, accuracy_test: 0.4894, Duration: 0:00:01.870996
# Epoch 180/200, Train Loss: 68.6216, Test Loss: 466.9224, accuracy_train: 0.9549, accuracy_test: 0.5319, Duration: 0:00:01.884354
# Epoch 181/200, Train Loss: 36.1230, Test Loss: 461.4688, accuracy_train: 0.9693, accuracy_test: 0.5957, Duration: 0:00:01.835635
# Epoch 182/200, Train Loss: 37.9451, Test Loss: 598.8911, accuracy_train: 0.9283, accuracy_test: 0.5319, Duration: 0:00:01.828537
# Epoch 183/200, Train Loss: 50.7531, Test Loss: 681.4852, accuracy_train: 0.9631, accuracy_test: 0.4468, Duration: 0:00:01.848185
# Epoch 184/200, Train Loss: 29.7349, Test Loss: 595.3185, accuracy_train: 0.9672, accuracy_test: 0.4468, Duration: 0:00:01.837459
# Epoch 185/200, Train Loss: 37.7665, Test Loss: 579.8031, accuracy_train: 0.9754, accuracy_test: 0.5106, Duration: 0:00:01.844536
# Epoch 186/200, Train Loss: 34.1096, Test Loss: 590.2509, accuracy_train: 0.9652, accuracy_test: 0.5957, Duration: 0:00:01.806818
# Epoch 187/200, Train Loss: 28.4920, Test Loss: 644.6281, accuracy_train: 0.9816, accuracy_test: 0.5319, Duration: 0:00:01.850405
# Epoch 188/200, Train Loss: 41.5613, Test Loss: 532.5840, accuracy_train: 0.9857, accuracy_test: 0.5319, Duration: 0:00:01.796657
# Epoch 189/200, Train Loss: 29.7513, Test Loss: 482.8121, accuracy_train: 0.9754, accuracy_test: 0.6170, Duration: 0:00:01.811364
# Epoch 190/200, Train Loss: 42.1688, Test Loss: 499.8130, accuracy_train: 0.9693, accuracy_test: 0.5532, Duration: 0:00:01.819175
# Epoch 191/200, Train Loss: 50.8607, Test Loss: 334.3702, accuracy_train: 0.9857, accuracy_test: 0.6170, Duration: 0:00:01.853471
# Epoch 192/200, Train Loss: 26.3340, Test Loss: 393.3323, accuracy_train: 0.9754, accuracy_test: 0.5745, Duration: 0:00:01.794059
# Epoch 193/200, Train Loss: 42.8423, Test Loss: 399.0380, accuracy_train: 0.9816, accuracy_test: 0.5745, Duration: 0:00:01.834897
# Epoch 194/200, Train Loss: 20.5367, Test Loss: 380.6637, accuracy_train: 0.9898, accuracy_test: 0.6170, Duration: 0:00:01.803707
# Epoch 195/200, Train Loss: 18.4067, Test Loss: 381.7291, accuracy_train: 0.9877, accuracy_test: 0.6596, Duration: 0:00:01.823459
# Epoch 196/200, Train Loss: 20.6938, Test Loss: 463.9940, accuracy_train: 0.9652, accuracy_test: 0.5532, Duration: 0:00:01.865566
# Epoch 197/200, Train Loss: 36.1785, Test Loss: 423.2432, accuracy_train: 0.9754, accuracy_test: 0.6170, Duration: 0:00:01.811826
# Epoch 198/200, Train Loss: 25.8636, Test Loss: 544.3592, accuracy_train: 0.9734, accuracy_test: 0.5957, Duration: 0:00:01.801417
# Epoch 199/200, Train Loss: 49.0769, Test Loss: 583.1192, accuracy_train: 0.9795, accuracy_test: 0.5745, Duration: 0:00:01.840930
# Epoch 200/200, Train Loss: 39.0300, Test Loss: 501.9389, accuracy_train: 0.9898, accuracy_test: 0.6383, Duration: 0:00:01.825604
